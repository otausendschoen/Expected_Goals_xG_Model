# %%
import pandas as pd
from statsbombpy import sb
from tqdm import tqdm
import os

# %%
# Set working directory to your desired folder
os.chdir("/Users/tirdodbehbehani/Desktop/BSE/Term 2/Geospatial Data Science and Economic Data Models/Football_Analysis")

# Confirm the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/tirdodbehbehani/Desktop/BSE/Term 2/Geospatial Data Science and Economic Data Models/Football_Analysis

# %%
# --- Step 1: Filter Competitions ---
comps = sb.competitions()

# Filter for male, non-youth competitions, and exclude specific competitions
comps_clean = comps[(comps['competition_gender'] == 'male') &
                    (comps['competition_youth'] == False) &
                    (~comps['competition_name'].isin([
                        'FIFA U20 World Cup',
                        'Indian Super league',
                        'Major League Soccer',
                        'North American League'
                    ]))]
# Out:
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
# --- Step 2: Retrieve Matches ---
matches_list = []
for _, row in comps_clean.iterrows():
    try:
        m = sb.matches(competition_id=row['competition_id'], season_id=row['season_id'])
        matches_list.append(m)
    except Exception as e:
        print(f"Error fetching matches for {row['competition_name']} ({row['season_name']}): {e}")

matches_shots = pd.concat(matches_list, ignore_index=True)
# Out:
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
# --- Step 3: Split Matches for Shots and Passes ---
# Convert match_date to datetime
matches_shots['match_date'] = pd.to_datetime(matches_shots['match_date'])
# For passes, filter matches from year >=2000
matches_passes = matches_shots[matches_shots['match_date'].dt.year >= 2000]

# %%
# --- Step 4: Download Events in Chunks ---
def get_events(match_ids):
    events_list = []
    for match_id in tqdm(match_ids, desc="Downloading events"):
        try:
            events = sb.events(match_id=match_id)
            events_list.append(events)
        except Exception as e:
            print(f"Error downloading events for match {match_id}: {e}")
    return pd.concat(events_list, ignore_index=True)

# %%
# For shots: get events for all match IDs in matches_shots
shot_match_ids = matches_shots['match_id'].unique()
events_shots = get_events(shot_match_ids)
# Out:
# Downloading events:   0%|          | 0/2801 [00:00<?, ?it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 1/2801 [00:00<38:33,  1.21it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 2/2801 [00:01<34:43,  1.34it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 3/2801 [00:02<33:15,  1.40it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 4/2801 [00:03<35:05,  1.33it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 5/2801 [00:03<34:58,  1.33it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 6/2801 [00:04<34:22,  1.36it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 7/2801 [00:05<33:14,  1.40it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 8/2801 [00:05<30:39,  1.52it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 9/2801 [00:06<35:17,  1.32it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 10/2801 [00:07<34:04,  1.36it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 11/2801 [00:08<35:20,  1.32it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 12/2801 [00:09<37:50,  1.23it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 13/2801 [00:09<35:59,  1.29it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 14/2801 [00:10<35:24,  1.31it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 15/2801 [00:11<36:41,  1.27it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 16/2801 [00:12<36:27,  1.27it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 17/2801 [00:12<35:03,  1.32it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 18/2801 [00:13<32:48,  1.41it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 19/2801 [00:14<32:27,  1.43it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 20/2801 [00:14<31:41,  1.46it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 21/2801 [00:15<30:46,  1.51it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 22/2801 [00:16<31:04,  1.49it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 23/2801 [00:17<35:34,  1.30it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 24/2801 [00:17<35:05,  1.32it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 25/2801 [00:18<34:17,  1.35it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 26/2801 [00:19<33:50,  1.37it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 27/2801 [00:19<34:28,  1.34it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 28/2801 [00:20<35:20,  1.31it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 29/2801 [00:21<35:49,  1.29it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          |
/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2795/2801 [35:58<00:04,  1.42it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2796/2801 [35:59<00:03,  1.42it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2797/2801 [36:00<00:02,  1.48it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2798/2801 [36:00<00:01,  1.66it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2799/2801 [36:01<00:01,  1.65it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2800/2801 [36:01<00:00,  1.68it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|██████████| 2801/2801 [36:02<00:00,  1.30it/s]

# %%
print(events_shots['type'].value_counts())

shots = events_shots[events_shots['type'] == "Shot"]
# Out:
# type
# Pass                 2788229
# Ball Receipt*        2622528
# Carry                2161380
# Pressure              900670
# Ball Recovery         287691
# Duel                  212490
# Clearance             126833
# Block                 105429
# Dribble                98989
# Foul Committed         85739
# Goal Keeper            85372
# Foul Won               81627
# Miscontrol             77991
# Dispossessed           70670
# Shot                   70553
# Interception           63729
# Dribbled Past          61622
# Substitution           17160
# Half Start             11396
# Half End               11396
# Injury Stoppage        10373
# 50/50                   8910
# Tactical Shift          7175
# Starting XI             5602
# Shield                  3664
# Referee Ball-Drop       2738
# Player Off              2626
# Player On               2601
# Bad Behaviour           2318
# Camera On               1837
# Error                   1255
# Offside                 1030
# Camera off               452
# Own Goal For             262
# Own Goal Against         262
# Name: count, dtype: int64

# %%
shots.shape
# Out:
# (70553, 121)

# %%
# For passes: get events for matches_passes
pass_match_ids = matches_passes['match_id'].unique()
events_passes = get_events(pass_match_ids)
# Filter events for passes only
passes = events_passes[events_passes['type'] == "Pass"]
# Out:
# Downloading events:   0%|          | 0/2768 [00:00<?, ?it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 1/2768 [00:01<1:27:07,  1.89s/it]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 2/2768 [00:02<54:21,  1.18s/it]  /Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 3/2768 [00:03<43:21,  1.06it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 4/2768 [00:04<41:31,  1.11it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 5/2768 [00:04<36:54,  1.25it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 6/2768 [00:05<36:12,  1.27it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 7/2768 [00:06<38:51,  1.18it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 8/2768 [00:07<40:07,  1.15it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 9/2768 [00:08<37:37,  1.22it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 10/2768 [00:08<36:02,  1.28it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 11/2768 [00:09<36:24,  1.26it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 12/2768 [00:10<33:40,  1.36it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   0%|          | 13/2768 [00:10<33:18,  1.38it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 14/2768 [00:11<34:02,  1.35it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 15/2768 [00:12<35:20,  1.30it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 16/2768 [00:13<33:37,  1.36it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 17/2768 [00:13<31:38,  1.45it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 18/2768 [00:14<28:44,  1.59it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 19/2768 [00:14<26:33,  1.72it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 20/2768 [00:15<27:30,  1.67it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 21/2768 [00:15<25:15,  1.81it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 22/2768 [00:16<27:38,  1.66it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 23/2768 [00:17<30:20,  1.51it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 24/2768 [00:17<29:29,  1.55it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 25/2768 [00:18<27:28,  1.66it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 26/2768 [00:18<25:37,  1.78it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 27/2768 [00:19<27:11,  1.68it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 28/2768 [00:19<25:14,  1.81it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 29/2768 [00:20<26:20,  1.73it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 30/2768 [00:21<27:13,  1.68it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 31/2768 [00:21<28:55,  1.58it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 32/2768 [00:22<26:53,  1.70it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 33/2768 [00:22<25:12,  1.81it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|          | 34/2768 [00:23<26:54,  1.69it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|▏         | 35/2768 [00:24<27:45,  1.64it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%|▏         | 36/2768 [00:24<26:44,  1.70it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events:   1%
/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2765/2768 [39:56<00:01,  2.15it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2766/2768 [39:56<00:00,  2.19it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|█████████▉| 2767/2768 [39:57<00:00,  2.21it/s]/Users/tirdodbehbehani/.pyenv/versions/myenv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloading events: 100%|██████████| 2768/2768 [39:57<00:00,  1.15it/s]

# %%
passes.shape
# Out:
# (2760335, 121)

# %%
import pandas as pd

# --- Step 1: Merge match-level data from Matches_Shots ---
# (Matches_Shots has columns: 'match_id', 'match_date', 'competition', 'season', ...)

shots = pd.merge(
    shots, 
    matches_shots[['match_id', 'match_date', 'competition', 'season']],
    on='match_id',
    how='left'
)

# --- Step 2: Merge competition info from comps_clean ---
# Here we merge on the competition and season names.
# Ensure that the columns in comps_clean to merge on are 'competition_name' and 'season_name'
shots = pd.merge(
    shots,
    comps_clean[['competition_id', 'competition_name', 'season_id', 'season_name']],
    left_on=['competition', 'season'],
    right_on=['competition_name', 'season_name'],
    how='left'
)

# Optionally, drop redundant columns from the merge if desired:
#shots.drop(columns=['competition_name', 'season_name'], inplace=True)

# --- Step 3: Convert match_date to datetime ---
shots['match_date'] = pd.to_datetime(shots['match_date'])

# --- Step 4: Clean the DataFrame ---
# Drop unwanted columns similar to the R select() statement:
cols_to_drop = ['carry_end_location', 'goalkeeper_end_location', 'tactics_lineup',
                'related_events', 'shot_freeze_frame', 'pass_end_location']
shots_clean = shots.drop(columns=cols_to_drop, errors='ignore')

# --- Step 5: "Unnest" shot.end_location ---
# We assume shot.end_location is a column with list-like values (e.g., [x, y]).
if 'shot_end_location' in shots_clean.columns:
    # Expand the list into two columns: shot.end_x and shot.end_y.
    # Make sure each element is a list or tuple of length 2.
    shots_clean[['shot.end_x', 'shot.end_y']] = pd.DataFrame(
        shots_clean['shot_end_location'].tolist(), 
        index=shots_clean.index
    )
    # Drop the original shot_end_location column.
    shots_clean.drop(columns=['shot_end_location'], inplace=True)
else:
    print("Column 'shot_end_location' not found in shots_clean.")

# At this point, shots_clean mimics the R workflow:
# - It has match_date (as datetime),
# - It has competition info merged via the names,
# - And the shot.end_location column has been expanded into shot.end_x and shot.end_y.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/myenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'match_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 28
#      16 shots = pd.merge(
#      17     shots,
#      18     comps_clean[['competition_id', 'competition_name', 'season_id', 'season_name']],
#    (...)
#      21     how='left'
#      22 )
#      24 # Optionally, drop redundant columns from the merge if desired:
#      25 #shots.drop(columns=['competition_name', 'season_name'], inplace=True)
#      26
#      27 # --- Step 3: Convert match_date to datetime ---
# ---> 28 shots['match_date'] = pd.to_datetime(shots['match_date'])
#      30 # --- Step 4: Clean the DataFrame ---
#      31 # Drop unwanted columns similar to the R select() statement:
#      32 cols_to_drop = ['carry_end_location', 'goalkeeper_end_location', 'tactics_lineup',
#      33                 'related_events', 'shot_freeze_frame', 'pass_end_location']
#
# File ~/.pyenv/versions/myenv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/myenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'match_date'

# %%
# Export the DataFrames as CSV files
shots.to_csv("shots_new.csv", index=False)
passes.to_csv("passes_new.csv", index=False)
